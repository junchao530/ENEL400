# %%
print("yes")
# Out:
# --- Small Signal Models ---
# rpi: 4 kΩ
# re: 24.8447 Ω
# ro: 120 kΩ
# gm: 40 mS
#
# --- Resistor Values ---
# rc: 3.07692 kΩ
# r1: 762.667 kΩ
# r2: 56 kΩ
#
# --- Biasing Values ---
# ib: 6.25 µA
# ic: 1 mA
# vce: 11.9231 V
# (0.04,
#  120000.0,
#  3076.923076923077,
#  11.923076923076923,
#  6.25e-06,
#  0.00100625,
#  24.84472049689441,
#  4000.0,
#  762666.6666666666,
#  55999.99999999999)
